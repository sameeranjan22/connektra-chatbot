# %%
import pandas as pd
import ast

# %%
df1=pd.read_csv("/content/Connectors.csv")

# %%
con_Trig=[]
for i in df1["Trigger Variables"]:
  result_list = ast.literal_eval(i)
  con_Trig.extend(result_list)
print(con_Trig)
con_Act=[]
for i in df1["Action Variables"]:
  result_list = ast.literal_eval(i)
  con_Act.extend(result_list)
print(con_Trig)
# Out:
# ['Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Update Contact', 'Get Campaigns', 'Get Contacts', 'Updated Record', 'Task Is Updated', 'Account Is Created', 'Watch Records', 'Lead Is Updated', 'Opportunity Is Created', 'Get Leads', 'Record Is Created', 'Quote Is Created', 'New Outbound Message', 'Record Is Updated', 'Account Is Updated', 'Get Queryable Objects', 'Case Is Created', 'Case Is Updated', 'Get Creatable Objects', 'Get Records For Object', 'Opportunity Is Updated', 'Record Created/Updated', 'Quote Is Updated', 'Get Updateable Objects', 'Opportunity Updated', 'Watch Jobs', 'Contact Is Created', 'Task Is Created', 'Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Update Contact', 'Get Campaigns', 'Get Contacts', 'Updated Record', 'Task Is Updated', 'Account Is Created', 'Watch Records', 'Lead Is Updated', 'Opportunity Is Created', 'Get Leads', 'Record Is Created', 'Quote Is Created', 'New Outbound Message', 'Record Is Updated', 'Account Is Updated', 'Get Queryable Objects', 'Case Is Created', 'Case Is Updated', 'Get Creatable Objects', 'Get Records For Object', 'Opportunity Is Updated', 'Record Created/Updated', 'Quote Is Updated', 'Get Updateable Objects', 'Opportunity Updated', 'Watch Jobs', 'Contact Is Created', 'Task Is Created', 'Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Update Contact', 'Get Campaigns', 'Get Contacts', 'Updated Record', 'Task Is Updated', 'Account Is Created', 'Watch Records', 'Lead Is Updated', 'Opportunity Is Created', 'Get Leads', 'Record Is Created', 'Quote Is Created', 'New Outbound Message', 'Record Is Updated', 'Account Is Updated', 'Get Queryable Objects', 'Case Is Created', 'Case Is Updated', 'Get Creatable Objects', 'Get Records For Object', 'Opportunity Is Updated', 'Record Created/Updated', 'Quote Is Updated', 'Get Updateable Objects', 'Opportunity Updated', 'Watch Jobs', 'Contact Is Created', 'Task Is Created', 'Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Update Contact', 'Get Campaigns', 'Get Contacts', 'Updated Record', 'Task Is Updated', 'Account Is Created', 'Watch Records', 'Lead Is Updated', 'Opportunity Is Created', 'Get Leads', 'Record Is Created', 'Quote Is Created', 'New Outbound Message', 'Record Is Updated', 'Account Is Updated', 'Get Queryable Objects', 'Case Is Created', 'Case Is Updated', 'Get Creatable Objects', 'Get Records For Object', 'Opportunity Is Updated', 'Record Created/Updated', 'Quote Is Updated', 'Get Updateable Objects', 'Opportunity Updated', 'Watch Jobs', 'Contact Is Created', 'Task Is Created', 'Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Update Contact', 'Get Campaigns', 'Get Contacts', 'Updated Record', 'Task Is Updated', 'Account Is Created', 'Watch Records', 'Lead Is Updated', 'Opportunity Is Created', 'Get Leads', 'Record Is Created', 'Quote Is Created', 'New Outbound Message', 'Record Is Updated', 'Account Is Updated', 'Get Queryable Objects', 'Case Is Created', 'Case Is Updated', 'Get Creatable Objects', 'Get Records For Object', 'Opportunity Is Updated', 'Record Created/Updated', 'Quote Is Updated', 'Get Updateable Objects', 'Opportunity Updated', 'Watch Jobs', 'Contact Is Created', 'Task Is Created', 'Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Upd ...
# ['Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Update Contact', 'Get Campaigns', 'Get Contacts', 'Updated Record', 'Task Is Updated', 'Account Is Created', 'Watch Records', 'Lead Is Updated', 'Opportunity Is Created', 'Get Leads', 'Record Is Created', 'Quote Is Created', 'New Outbound Message', 'Record Is Updated', 'Account Is Updated', 'Get Queryable Objects', 'Case Is Created', 'Case Is Updated', 'Get Creatable Objects', 'Get Records For Object', 'Opportunity Is Updated', 'Record Created/Updated', 'Quote Is Updated', 'Get Updateable Objects', 'Opportunity Updated', 'Watch Jobs', 'Contact Is Created', 'Task Is Created', 'Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Update Contact', 'Get Campaigns', 'Get Contacts', 'Updated Record', 'Task Is Updated', 'Account Is Created', 'Watch Records', 'Lead Is Updated', 'Opportunity Is Created', 'Get Leads', 'Record Is Created', 'Quote Is Created', 'New Outbound Message', 'Record Is Updated', 'Account Is Updated', 'Get Queryable Objects', 'Case Is Created', 'Case Is Updated', 'Get Creatable Objects', 'Get Records For Object', 'Opportunity Is Updated', 'Record Created/Updated', 'Quote Is Updated', 'Get Updateable Objects', 'Opportunity Updated', 'Watch Jobs', 'Contact Is Created', 'Task Is Created', 'Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Update Contact', 'Get Campaigns', 'Get Contacts', 'Updated Record', 'Task Is Updated', 'Account Is Created', 'Watch Records', 'Lead Is Updated', 'Opportunity Is Created', 'Get Leads', 'Record Is Created', 'Quote Is Created', 'New Outbound Message', 'Record Is Updated', 'Account Is Updated', 'Get Queryable Objects', 'Case Is Created', 'Case Is Updated', 'Get Creatable Objects', 'Get Records For Object', 'Opportunity Is Updated', 'Record Created/Updated', 'Quote Is Updated', 'Get Updateable Objects', 'Opportunity Updated', 'Watch Jobs', 'Contact Is Created', 'Task Is Created', 'Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Update Contact', 'Get Campaigns', 'Get Contacts', 'Updated Record', 'Task Is Updated', 'Account Is Created', 'Watch Records', 'Lead Is Updated', 'Opportunity Is Created', 'Get Leads', 'Record Is Created', 'Quote Is Created', 'New Outbound Message', 'Record Is Updated', 'Account Is Updated', 'Get Queryable Objects', 'Case Is Created', 'Case Is Updated', 'Get Creatable Objects', 'Get Records For Object', 'Opportunity Is Updated', 'Record Created/Updated', 'Quote Is Updated', 'Get Updateable Objects', 'Opportunity Updated', 'Watch Jobs', 'Contact Is Created', 'Task Is Created', 'Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Update Contact', 'Get Campaigns', 'Get Contacts', 'Updated Record', 'Task Is Updated', 'Account Is Created', 'Watch Records', 'Lead Is Updated', 'Opportunity Is Created', 'Get Leads', 'Record Is Created', 'Quote Is Created', 'New Outbound Message', 'Record Is Updated', 'Account Is Updated', 'Get Queryable Objects', 'Case Is Created', 'Case Is Updated', 'Get Creatable Objects', 'Get Records For Object', 'Opportunity Is Updated', 'Record Created/Updated', 'Quote Is Updated', 'Get Updateable Objects', 'Opportunity Updated', 'Watch Jobs', 'Contact Is Created', 'Task Is Created', 'Updated Field On Record', 'New Contact', 'New Task', 'New Lead', 'New Account', 'New Opportunity', 'Get Fields For Object', 'New Record', 'Lead Is Created', 'Contact Is Updated', 'Upd ...

# %%
Triggers=list(set(con_Trig))
Actions=list(set(con_Act))

# %%
print(Triggers)
# Out:
# ['New Engagement', 'List Of Lead Fields', 'New Order', 'Email Is Opened', 'Watch Leads', 'New Invoice Item', 'Configure Webhooks', 'Tag Added To Conversation', 'Watch Views', 'New Registrant', 'Watch Broadcast Messages', 'Quote Is Accepted', 'New Group', 'Watch Lists', 'Board Is Created', 'New Calendar Task', 'Contact Updated', 'New Employee', 'New Public Message Posted Anywhere', 'Link Is Clicked', 'Refund Created', 'Invoice Is Created', 'New Post', 'Watch Tickets', 'New Source', 'List Enabled Webhook Events', 'Form Is Submitted', 'Folder Is Created', 'Get Queryable Objects', 'New Forum', 'New View', 'Watch Invoices', 'Watch Payment Link Partially Paid', 'Post Is Updated', 'New Users', 'Profile Updates', 'New Charge', 'New Sms', 'Meeting Created', 'Contact Trigger', 'New Subscriber (Instant)', 'Watch Employees', 'New Lead', 'Watch Users', 'Opportunity Is Created', 'New Field In Table', 'New Message Posted To Channel', 'Record Is Created', 'New Company Property Change', 'New Ticket', 'Campaign Is Sent', 'Quote Is Created', 'New Event Type', 'New Plan', 'Ticket Solved', 'Order Is Updated', 'New Opportunity', 'Watch Submissions For Form', 'New Comment', 'Invitee Created', 'New Deal Property Change', 'New Campaign Sent', 'Opportunity Updated', 'Updated Deal Stage', 'New Conversation', 'New Charge (Legacy)', 'User Is Created', 'Invitee Created (Organization)', 'New Deals', 'Watch Alerts', 'Payment Link Paid', 'Watch Payment Link Paid', 'New/Updated Record', 'New Contact In List', 'New File', 'Record Is Created In View', 'Product Updated', 'Link Clicked', 'List Workspaces', 'Payment Dispute Lost', 'New Payment Link', 'Watch Deals', 'Get All Tickets', 'Time Zone', 'Specific Column Value Changed In Board', 'New Submission', 'Record Created/Updated', 'New Companies', 'Order Is Paid', 'New Form Is Created', 'New Dispute', 'Product Is Deleted', 'New Transcription', 'Campaign Is Created', 'Get Updateable Objects', 'Lead Added Email', 'Deal Updated', 'List Drives', 'Task Is Updated', 'New Records', 'Webinar Is Created', 'Cancelled Subscription', 'Payment Failed', 'Contact Is Created', 'Test Me', 'Invoice Expired', 'Invoice Payment Is Failed', 'Get Campaigns', 'Form Is Created', 'Invitee Is Created', 'View Is Created', 'Watch Items', 'Watch New Event', 'New Brand', 'Ticket Pending', 'New Comment (Instant)', 'New Products', 'Failed Payment', 'Quote Is Updated', 'Order Is Created', 'Subscription Is Cancelled', 'New Open', 'User Deleted', 'New User', 'New Event', 'Lead Trigger', 'Watch Comments', 'New Organization', 'Payment Captured', 'New Event (Legacy)', 'New Comments', 'Watch Categories', 'List Payment Links', 'Watch Companies', 'Invoice Paid', 'Group Is Created', 'Product Is Created', 'Payment Dispute Won', 'Column Value Is Changed On Board', 'Spreadsheet Row Is Created/Updated', 'Updated Field On Record', 'New Mention', 'New Email Event', 'New Refund', 'New Department', 'Watch Invoice Paid', 'Updated Blog Posts', 'New Customer', 'New Agent', 'Get Fields For Object', 'Update Contact', 'Watch Events', 'Watch Meetings', 'Ticket Is Created', 'Watch Media Items', 'Get Leads', 'Cancelled Schedule Subscription', 'New Events', 'Issue Status Changed', 'New Lead (Legacy)', 'List Prices For Payment Link', 'Opportunity Is Updated', 'Watch Notifications', 'Updated Post', 'New Issue', 'Contact Is Updated', 'Refund Is Issued', 'Get All Contacts', 'Watch Invoice Partially Paid', 'Lead Is Created', 'Watch Posts', 'Updated Subscription', 'Invoice Payment Succeeded', 'Watch Subscriptions Timeline For Portal', 'New Company', 'New Item', 'New Ticket Property Change', 'New Channel', 'New Record In View', 'New Message', 'Watch Tasks', 'Watch Tags', 'Product Is Updated', 'New Label', 'Watch Changes', 'New Admin', 'Case Is Updated', 'Get All Companies', 'Invoice Is Paid', 'Invitee Is Canceled', 'New Thread', 'New Contacts', 'List Forms', 'Company Is Deleted', 'Item Is Created In Board', 'Watch Records', 'Post Is Created', 'New Meeting', 'Watch Organizations', ' ...

# %%
print(Actions)
# Out:
# ['Find Campaign By Id', 'Create Workspace', 'Add Comment To Ticket', 'Search Item', 'Find Record(S)', 'Create Time Off Request', 'Make Api Request (Beta)', 'Send Private Channel Message', 'Add Subscriber To Tag', 'Get Payment', 'Update Member', 'Create Account', 'Update Invoice', 'List Payouts', 'Find Category', 'Update Message', 'Create Price', 'Delete Organization', 'Post Message To Chatter Feed', 'Update Invoice Item', 'List Projects', 'Join Channel', 'Edit Campaign Template Content', 'Find Deal', 'Create Payment Link', 'Update Organization', 'Get Form', 'Complete Reminder', 'Create Campaign', 'Find/Create Campaign', 'Find/Create Contact', 'Find Post', 'Delete Record', 'Unsubscribe Email', 'Create Customer', 'Update Cell', 'Get User', 'Search Subscribers', 'Delete List', 'Create Update', 'List Comments', 'Delete Campaign', 'Add Note', 'List Reminders', 'Add Contact To Campaign', 'List Call Logs', 'List Contacts', 'Set Channel Purpose', 'Update Webinar Registrantâ€™S Status', 'Get Group', 'Create Deal', 'Create Issue', 'Add Tag To Subscriber', 'Remove Label From Email', 'Create Case', 'Update Coupon', 'Search Lists', 'Find/Create Employee', 'Update Refund', 'Find Customer By Id', 'Search Categories', 'Create Text File', 'Delete Project', 'Delete Tag', 'Find Company By Domain', 'Find Form By Id', 'Create Invoice Item', 'List Invoices', 'Update Email Subscription', 'Delete User', 'List Owners', 'Get Meeting', "List Board'S Groups", 'Get Reminder', 'Search User By Email', 'Upload File', 'Get File Uploaded Via Form', 'List Meetings', 'Create Calendar Task', 'Create Subitem', 'Search Order By Id', 'Get Ticket', 'Remove Member Tag (Tag List)', 'Retrieve Payout', 'Archive Deal', 'Create Lead (Legacy)', 'List Conversations', 'Find User By Id', 'Search Agent', 'List Tickets', 'Find User By Username', 'Archive Channel', 'Find Deals Associated With Contact', 'Send Invoice', 'Find Payment', 'Find Product', 'Delete Ticket', 'Create Category', 'Update Spreadsheet Row', 'Update Company', 'Add Contact To Workflow', 'Add Member To Segment', 'Delete Calendar Task', 'Update Task', 'Upsert Record', 'Create Meeting Registrant', 'Search Contacts', "Get Summary Of Who'S Out", 'Search Tasks', 'List Files', 'List Jobs', 'List Webinar Absentees', 'Find Lead', 'Get Members', 'Get Ticket By Id', 'Add Multiple Rows', 'Get Campaign By Id', 'Get File Public Url', 'Delete Deal', 'Update Issue', 'Find Record', 'Associate Deal With Company', 'Add Watcher To Issue', 'Create Attachment', 'Find/Create User', 'Send Incoming Message', 'Make Phone Call', 'Add Reminder', 'Search Deals', 'Create Product', 'Search Deal', 'Kick User', 'Create Invoice Line Item', 'Remove Subscriber', 'Submit Data To Form', 'Get Channel', 'Delete Sheet', 'Get Lead', 'Assign Issue', 'Search Organizations', 'Get Tag By Id', 'Search Leads', 'Cancel Payout', 'Search Tags', 'Find Ticket By Id', 'List Member Tags', 'Find Customer By Email', 'Void Invoice', 'List Meeting Registrants', 'Get Company', 'Get User Details', 'List Group Items', 'Add Comment To Issue', 'Retrieve Webinar', 'Update Payment Intent', 'Get Comment', 'Delete Lead', 'Update Range Values', 'Delete Coupon', 'Append Values', 'List Groups', 'Search Items By Column Value', 'Move Item To Group', 'Create Folder', 'Delete Company', 'Update Comment', 'Create/Update User', 'Update User', 'Find Charge', 'Create/Update Tag', 'Retrieve Refund', 'Create Form Submission', 'Copy Spreadsheet', 'Get Task', 'Delete Call', 'Update Record', 'Find Deal By Id', 'Get Issue', 'Invite User To Channel', 'Get Subscriber', 'Post Comment', 'Get Product', 'Update Employee', 'Get Form By Id', 'Charge Card', 'List Message Media', 'Find Invoice', 'Get Tag', 'Find Customer', 'Create Meeting', 'Retrieve Payment Intent', 'Capture Payment', 'Delete Message', 'Create Worksheet', 'Search Tickets', 'Delete Form', 'Find Company By Id', 'Create Board', 'Send Direct Message', 'Search Ticket', 'Find Product By Id', 'Create Order', 'Make Api Call', 'Search Product By N ...

# %%
apis = ["salesforce", "hubspot", "slack", "Google Sheets", "gmail", "bitrix24", "calendly", "mailchimp", "stripe", "airtable", "twilio", "razorpay", "figma", "intercom", "wordpress", "zoom", "typeform", "jira", "bamboohr", "zendesk", "monday"]

# %%
# !pip install spello
# Out:
# Collecting spello
#   Downloading spello-1.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: nltk<4,>=3.4.5 in /usr/local/lib/python3.10/dist-packages (from spello) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4,>=3.4.5->spello) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4,>=3.4.5->spello) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4,>=3.4.5->spello) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4,>=3.4.5->spello) (4.66.1)
# Installing collected packages: spello
# Successfully installed spello-1.3.0

# %%
from spello.model import SpellCorrectionModel
sp=SpellCorrectionModel(language='en')

# %%
sp2.spell_correct("send an mail from mailchamp and trext it on sl!%@k ")
# Out:
# DEBUG:spello.settings:Symspell suggestions: [('gmail', 1), ('email', 1), ('gmail', 1), ('email', 1)]
# DEBUG:spello.settings:Phoneme suggestions: []
# DEBUG:spello.settings:Symspell suggestions: [('mailchimp', 1), ('mailchimp', 1), ('mailchimp', 1)]
# DEBUG:spello.settings:Phoneme suggestions: [('mailchimp', 1), ('mailchimp', 1), ('mailchimp', 1)]
# DEBUG:spello.settings:Symspell suggestions: [('text', 1), ('text', 1), ('text', 1)]
# DEBUG:spello.settings:Phoneme suggestions: []
# DEBUG:spello.settings:Symspell suggestions: [('slack', 3), ('slack', 3)]
# DEBUG:spello.settings:Phoneme suggestions: []
# DEBUG:spello.settings:Suggestions dict from phoneme and symspell are: {'mail': ['gmail', 'email'], 'mailchamp': ['mailchimp'], 'trext': ['text'], 'sl!%@k': ['slack']}
# DEBUG:spello.settings:text after context model: send an email from mailchimp and text it on slack
# DEBUG:spello.settings:Spell-correction Results {'original_text': 'send an mail from mailchamp and trext it on sl!%@k', 'spell_corrected_text': 'send an email from mailchimp and text it on slack', 'correction_dict': {'mail': 'email', 'mailchamp': 'mailchimp', 'trext': 'text', 'sl!%@k': 'slack'}}
# {'original_text': 'send an mail from mailchamp and trext it on sl!%@k',
#  'spell_corrected_text': 'send an email from mailchimp and text it on slack',
#  'correction_dict': {'mail': 'email',
#   'mailchamp': 'mailchimp',
#   'trext': 'text',
#   'sl!%@k': 'slack'}}

# %%
# sp.load("/content/model.pkl")

# %%
data=[]

# %%
data=Triggers+Actions+apis

# %%
sp.train(data)
# Out:
# Spello training started..
# DEBUG:spello.settings:Spello training started..
# Context model training started ...
# DEBUG:spello.settings:Context model training started ...
# Symspell training started ...
# DEBUG:spello.settings:Symspell training started ...
# Phoneme training started ...
# DEBUG:spello.settings:Phoneme training started ...
# Spello training completed successfully ...
# DEBUG:spello.settings:Spello training completed successfully ...

# %%
sp.spell_correct("Saladforces")
# Out:
# DEBUG:spello.settings:Symspell suggestions: [('salesforce', 3), ('salesforce', 3)]
# DEBUG:spello.settings:Phoneme suggestions: []
# DEBUG:spello.settings:Suggestions dict from phoneme and symspell are: {'saladforces': ['salesforce']}
# DEBUG:spello.settings:text after context model: salesforce
# DEBUG:spello.settings:Spell-correction Results {'original_text': 'Saladforces', 'spell_corrected_text': 'salesforce', 'correction_dict': {'Saladforces': 'salesforce'}}
# {'original_text': 'Saladforces',
#  'spell_corrected_text': 'salesforce',
#  'correction_dict': {'Saladforces': 'salesforce'}}

# %%
sp.spell_correct("sunday")
# Out:
# DEBUG:spello.settings:Symspell suggestions: [('monday', 2), ('monday', 2)]
# DEBUG:spello.settings:Phoneme suggestions: [('send', 3), ('send', 3), ('sent', 4)]
# DEBUG:spello.settings:Suggestions dict from phoneme and symspell are: {'sunday': ['monday', 'send', 'sent']}
# DEBUG:spello.settings:text after context model: monday
# DEBUG:spello.settings:Spell-correction Results {'original_text': 'sunday', 'spell_corrected_text': 'monday', 'correction_dict': {'sunday': 'monday'}}
# {'original_text': 'sunday',
#  'spell_corrected_text': 'monday',
#  'correction_dict': {'sunday': 'monday'}}

# %%
sp.spell_correct("slac@k")
# Out:
# DEBUG:spello.settings:Symspell suggestions: [('slack', 1), ('slack', 1), ('slack', 1)]
# DEBUG:spello.settings:Phoneme suggestions: [('slack', 1), ('slack', 1), ('slack', 1)]
# DEBUG:spello.settings:Suggestions dict from phoneme and symspell are: {'slac@k': ['slack']}
# DEBUG:spello.settings:text after context model: slack
# DEBUG:spello.settings:Spell-correction Results {'original_text': 'slac@k', 'spell_corrected_text': 'slack', 'correction_dict': {'slac@k': 'slack'}}
# {'original_text': 'slac@k',
#  'spell_corrected_text': 'slack',
#  'correction_dict': {'slac@k': 'slack'}}

# %%
sp.spell_correct("google-sheets")
# Out:
# DEBUG:spello.settings:Symspell suggestions: []
# DEBUG:spello.settings:Phoneme suggestions: []
# DEBUG:spello.settings:Suggestions dict from phoneme and symspell are: {}
# DEBUG:spello.settings:text after context model: google-sheets
# DEBUG:spello.settings:Spell-correction Results {'original_text': 'google-sheets', 'spell_corrected_text': 'google-sheets', 'correction_dict': {}}
# {'original_text': 'google-sheets',
#  'spell_corrected_text': 'google-sheets',
#  'correction_dict': {}}

# %%
sp.spell_correct("Saladforces")

# %%
sp.spell_correct("Saladforces")

# %%
sp.save("/content/spell_model.pkl")
# Out:
# '/content/spell_model.pkl/model.pkl'
